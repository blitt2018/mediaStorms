# %%
import os
import pandas as pd
import numpy as np

# %%
#just need to inspect the file that was written with results from the final model on the test set
randomSeeds = [135, 200, 60, 85, 92]

baseDir = "/shared/3/projects/newsDiffusion/models/3.0-crossModelAblation/finalOnTest/"

for seed in randomSeeds: 
    currDf = pd.read_csv(baseDir + str(seed) + "testDf.tsv", sep="\t")
    np.corrcoef(currDf["ground_truth"], currDf["scaledSims"])[0, 1]
# Out:
# 0.8160774146291654
# 0.8374484270334323
# 0.8432352632368516
# 0.8454292759632333
# 0.8399187512694455

# %%
currDf
# Out:
#      Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1 url1_lang url2_lang  \
# 0             0             0               0        en        en
# 1             1             1               1        en        en
# 2             2             2               2        en        en
# 3             3             3               3        en        en
# 4             4             4               4        en        en
# ..          ...           ...             ...       ...       ...
# 231         231           231            4555        en        en
# 232         232           232            4556        en        en
# 233         233           233            4557        en        en
# 234         234           234            4558        en        en
# 235         235           235            4559        en        en
#
#                    pair_id                                              link1  \
# 0    1484189203_1484121193  https://wsvn.com/news/local/broward/police-2-m...
# ...
