# %%
import transformers
import pandas as pd
import json
import os

# %% [markdown]
# ## resources for SBERT
# https://github.com/UKPLab/sentence-transformers/blob/master/examples/training/sts/training_stsbenchmark.py
# https://www.sbert.net/examples/training/sts/README.html#loss-function
# https://github.com/cerlymarco/MEDIUM_NoteBook/blob/master/Siamese_Dual_BERT/Siamese_Dual_BERT.ipynb

# %% [markdown]
# ## start by getting the data in the right format for training

# %%
outerFolder = "/shared/3/projects/benlitterer/agendaSetting/trainingHtml"

dfList = []
for folderNum in os.listdir(outerFolder): 
    innerFolder = outerFolder + "/" + folderNum 
    for innerFileName in os.listdir(innerFolder): 
        innerPathName = outerFolder + "/" + folderNum + "/" + innerFileName
        if "json" in innerPathName: 
            with open(innerPathName, "r") as f: 
                data = json.loads(f.read())
            df = pd.json_normalize(data)
            df["id"] = innerFileName.split(".")[0]
            dfList.append(df)

# %%
fullDf = pd.concat(dfList).reset_index(drop=True)

# %%
leanDf = fullDf[["id", "title", "url", "source_url", "text"]]

# %%
groundTruths = pd.read_csv("/shared/3/projects/benlitterer/agendaSetting/trainingDataV2.csv")
print(groundTruths.shape)
groundTruths.head(3)

# %%
groundTruths.loc[(groundTruths["url1_lang"] == "en") & (groundTruths["url2_lang"] == "en")].shape
# Out:
# (1800, 14)

# %%
groundTruths[["id1", "id2"]] = groundTruths["pair_id"].str.split("_", expand=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-92839cc8a47e> in <module>
# ----> 1 groundTruths[["id1", "id2"]] = groundTruths["pair_id"].str.split("_", expand=True)
#
# /opt/anaconda/lib/python3.8/site-packages/pandas/core/strings/accessor.py in wrapper(self, *args, **kwargs)
#      99                 )
#     100                 raise TypeError(msg)
# --> 101             return func(self, *args, **kwargs)
#     102
#     103         wrapper.__name__ = func_name
#
# /opt/anaconda/lib/python3.8/site-packages/pandas/core/strings/accessor.py in split(self, pat, n, expand)
#     744     @forbid_nonstring_types(["bytes"])
#     745     def split(self, pat=None, n=-1, expand=False):
# --> 746         result = self._data.array._str_split(pat, n, expand)
#     747         return self._wrap_result(result, returns_string=expand, expand=expand)
#     748
#
# AttributeError: 'PandasArray' object has no attribute '_str_split'

# %%
leanDf = leanDf[["id", "text"]]

# %%
#merge text for the first id, id1
leanDf1 = leanDf.rename(columns = {"id":"id1","text":"text1"})
firstMerge = pd.merge(groundTruths, leanDf1, how="left", on="id1")
firstMerge.head(3)
# Out:
#   url1_lang url2_lang                pair_id  \
# 0        en        en  1484084337_1484110209
# 1        en        en  1484396422_1483924666
# 2        en        en  1484698254_1483758694
#
#                                                link1  \
# 0  https://www.washingtonpost.com/local/virginia-...
# 1  https://www.stlucianewsonline.com/guyana-three...
# 2  https://www.teaparty.org/trump-brings-in-2020-...
#
#                                                link2  \
# 0  https://www.washingtonpost.com/world/the_ameri...
# 1  https://www.thestar.com/news/world/europe/2020...
# 2  https://www.timesofisrael.com/trump-says-he-do...
#
#                                             ia_link1  \
# 0  https://web.archive.org/web/www.washingtonpost...
# 1  https://web.archive.org/web/www.stlucianewsonl...
# 2  https://web.archive.org/web/www.teaparty.org/t...
#
#                                             ia_link2  Geography  Entities  \
# 0  https://web.archive.org/web/www.washingtonpost...        4.0       4.0
# 1  https://web.archive.org/web/www.thestar.com/ne...        4.0       4.0
# 2  https://web.archive.org/web/www.timesofisrael....        1.0       2.0
#
#    Time  Narrative   Overall     Style      Tone         id1         id2  \
# 0   1.0   4.000000  4.000000  1.666667  2.000000  1484084337  1484110209
# 1   1.0   4.000000  3.666667  1.666667  1.333333  1484396422  1483924666
# 2   1.0   2.333333  2.333333  1.000000  1.333333  1484698254  1483758694
#
#                                                text1
# 0  MARTINSBURG, W.Va. — A suspected drunken drive...
# 1  Share This On:\n\nPin 11 Shares\n\n(NEWS ROOM ...
# 2  (Breitbart) – President Donald Trump welcomed ...

# %%
leanDf2 = leanDf.rename(columns = {"id":"id2","text":"text2"})
merged = pd.merge(firstMerge, leanDf2, how="left", on="id2")
merged.head(3)
# Out:
#   url1_lang url2_lang                pair_id  \
# 0        en        en  1484084337_1484110209
# 1        en        en  1484396422_1483924666
# 2        en        en  1484698254_1483758694
#
#                                                link1  \
# 0  https://www.washingtonpost.com/local/virginia-...
# 1  https://www.stlucianewsonline.com/guyana-three...
# 2  https://www.teaparty.org/trump-brings-in-2020-...
#
#                                                link2  \
# 0  https://www.washingtonpost.com/world/the_ameri...
# 1  https://www.thestar.com/news/world/europe/2020...
# 2  https://www.timesofisrael.com/trump-says-he-do...
#
#                                             ia_link1  \
# 0  https://web.archive.org/web/www.washingtonpost...
# 1  https://web.archive.org/web/www.stlucianewsonl...
# 2  https://web.archive.org/web/www.teaparty.org/t...
#
#                                             ia_link2  Geography  Entities  \
# 0  https://web.archive.org/web/www.washingtonpost...        4.0       4.0
# 1  https://web.archive.org/web/www.thestar.com/ne...        4.0       4.0
# 2  https://web.archive.org/web/www.timesofisrael....        1.0       2.0
#
#    Time  Narrative   Overall     Style      Tone         id1         id2  \
# 0   1.0   4.000000  4.000000  1.666667  2.000000  1484084337  1484110209
# 1   1.0   4.000000  3.666667  1.666667  1.333333  1484396422  1483924666
# 2   1.0   2.333333  2.333333  1.000000  1.333333  1484698254  1483758694
#
#                                                text1  \
# 0  MARTINSBURG, W.Va. — A suspected drunken drive...
# 1  Share This On:\n\nPin 11 Shares\n\n(NEWS ROOM ...
# 2  (Breitbart) – President Donald Trump welcomed ...
#
#                                                text2
# 0  PORT-AU-PRINCE, Haiti — Haitian President Jove...
# 1  BERLIN - A fire at a zoo in western Germany in...
# 2  PALM BEACH, United States — US President Donal...

# %%
mergedFull = merged.dropna(subset=["text1", "text2"])

# %%
mergedFull.shape
# Out:
# (4032, 18)

# %%
mergedFull[(mergedFull["url1_lang"] == "en") & (mergedFull["url2_lang"] == "en")]
# Out:
#      url1_lang url2_lang                pair_id  \
# 0           en        en  1484084337_1484110209
# 1           en        en  1484396422_1483924666
# 2           en        en  1484698254_1483758694
# 3           en        en  1576314516_1576455088
# 4           en        en  1484036253_1483894099
# ...        ...       ...                    ...
# 3444        en        en  1602628318_1522567203
# 3445        en        en  1558724916_1578120789
# 3446        en        en  1516170185_1515943366
# 3447        en        en  1511216591_1511221676
# 3448        en        en  1502772737_1502868502
#
#                                                   link1  \
# 0     https://www.washingtonpost.com/local/virginia-...
# 1     https://www.stlucianewsonline.com/guyana-three...
# 2     https://www.teaparty.org/trump-brings-in-2020-...
# 3     https://gadgets.ndtv.com/apps/news/zomato-uber...
# 4     https://news.yahoo.com/india-approves-third-mo...
# ...                                                 ...
# 3444  https://communities.vmware.com/message/2948357...
# 3445  https://www.cnbctv18.com/healthcare/you-can-no...
# 3446  http://www.looptonga.com/global-news/thai-sold...
# 3447  https://www.sowetanlive.co.za/news/south-afric...
# 3448  https://www.citynews1130.com/2020/01/23/migran...
#
#                                                   link2  \
# 0     https://www.washingtonpost.com/world/the_ameri...
# 1     https://www.thestar.com/news/world/europe/2020...
# 2     https://www.timesofisrael.com/trump-says-he-do...
# 3     https://gadgets.ndtv.com/internet/news/indian-...
# 4     https://www.channelnewsasia.com/news/asia/indi...
# ...                                                 ...
# 3444  https://communities.vmware.com/message/2927239...
# 3445  https://www.business-standard.com/article/opin...
# 3446  https://www.itv.com/news/2020-02-09/thai-soldi...
# 3447  https://www.iol.co.za/news/south-africa/gauten...
# 3448  https://www.business-standard.com/article/pti-...
#
#                                                ia_link1  \
# 0     https://web.archive.org/web/www.washingtonpost...
# 1     https://web.archive.org/web/www.stlucianewsonl...
# 2     https://web.archive.org/web/www.teaparty.org/t...
# 3     https://web.archive.org/web/gadgets.ndtv.com/a...
# 4     https://web.archive.org/web/news.yahoo.com/ind...
# ...                                                 ...
# 3444  https://web.archive.org/web/communities.vmware...
# 3445  https://web.archive.org/web/www.cnbctv18.com/h...
# 3446  https://web.archive.org/web/www.looptonga.com/...
# 3447  https://web.archive.org/web/www.sowetanlive.co...
# 3448  https://web.archive.org/web/www.citynews1130.c...
#
#                                                ia_link2  Geography  Entities  \
# 0     https://web.archive.org/web/www.washingtonpost...        4.0  4.000000
# 1     https://web.archive.org/web/www.thestar.com/ne...        4.0  4.000000
# 2     https://web.archive.org/web/www.timesofisrael....        1.0  2.000000
# 3     https://web.archive.org/web/gadgets.ndtv.com/i...        1.0  2.333333
# 4     https://web.archive.org/web/www.channelnewsasi...        1.0  1.250000
# ...                                                 ...        ...       ...
# 3444  https://web.archive.org/web/communities.vmware...        4.0  3.000000
# 3445  https://web.archive.org/web/www.business-stand...        1.0  4.000000
# 3446  https://web.archive.org/web/www.itv.com/news/2...        1.0  2.000000
# 3447  https://web.archive.org/web/www.iol.co.za/news...        1.0  1.000000
# 3448  https://web.archive.org/web/www.business-stand...        1.0  1.000000
#
#           Time  Narrative   Overall     Style      Tone         id1  \
# 0     1.000000   4.000000  4.000000  1.666667  2.000000  1484084337
# 1     1.000000   4.000000  3.666667  1.666667  1.333333  1484396422
# 2     1.000000   2.333333  2.333333  1.000000  1.333333  1484698254
# 3     2.666667   1.666667  2.000000  1.666667  1.666667  1576314516
# 4     1.000000   1.250000  1.250000  1.000000  1.000000  1484036253
# ...        ...        ...       ...       ...       ...         ...
# 3444  1.000000   2.000000  3.000000  1.000000  1.000000  1602628318
# 3445  3.000000   4.000000  4.000000  2.000000  1.000000  1558724916
# 3446  1.000000   2.000000  1.000000  3.000000  1.000000  1516170185
# 3447  1.000000   1.000000  1.000000  1.000000  1.000000  1511216591
# 3448  1.000000   1.000000  1.000000  1.000000  1.000000  1502772737
#
#              id2                                              text1  \
# 0     1484110209  MARTINSBURG, W.Va. — A suspected drunken drive...
# 1     1483924666  Share This On:\n\nPin 11 Shares\n\n(NEWS ROOM ...
# 2     1483758694  (Breitbart) – President Donald Trump welcomed ...
# 3     1576455088  Uber has sold its online food-ordering busines...
# 4     1483894099  BENGALURU (Reuters) - India has approved its t...
# ...          ...                                                ...
# 3444  1522567203  Hello,\n\nWe are preparing to move our environ...
# 3445  1578120789  You can now consult with your doctors through ...
# 3446  1515943366  Jakraphanth Thomma on Saturday killed his comm...
# 3447  1511221676  The bodies of the victims were found lying in ...
# 3448  1502868502  CIUDAD HIDALGO, Mexico — Hundreds of Central A...
#
#                                                   text2
# 0     PORT-AU-PRINCE, Haiti — Haitian President Jove...
# 1     BERLIN - A fire at a zoo in western Germany in...
# 2     PALM BEACH, United States — US President Donal...
# 3     Rapid digitisation and growth in both online b...
# 4     BANGALORE: India plans to make a fresh attempt...
# ...                                                 ...
# 3444  I'm running vCenter 6.7 w/ three host also run...
# 3445  India is doing a commendable job in fighting t...
# 3446  Medics carry a stretcher towards a Thai shoppi...
# 3447  Johannesburg - Gauteng police on Saturday said...
# 3448  Hundreds of Central American migrants crossed ...
#
# [1690 rows x 18 columns]

# %%
mergedFull.to_csv("/shared/3/projects/benlitterer/localNews/NetworkMVP/enTrainData.csv", sep="\t")
