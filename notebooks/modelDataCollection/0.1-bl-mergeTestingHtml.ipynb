# %%
import transformers
import pandas as pd
from tqdm import tqdm 
import json
import os

# %%
outerFolder = "/shared/3/projects/newsDiffusion/data/raw/test"

dfList = []
for folderNum in tqdm(os.listdir(outerFolder)): 
    innerFolder = outerFolder + "/" + folderNum 
    for innerFileName in os.listdir(innerFolder): 
        innerPathName = outerFolder + "/" + folderNum + "/" + innerFileName
        if "json" in innerPathName: 
            with open(innerPathName, "r") as f: 
                data = json.loads(f.read())
            df = pd.json_normalize(data)
            df["id"] = innerFileName.split(".")[0]
            dfList.append(df)
# Out:
# 100%|██████████| 100/100 [00:43<00:00,  2.32it/s]

# %%
fullDf = pd.concat(dfList).reset_index(drop=True)

# %%
leanDf = fullDf[["id", "title", "url", "source_url", "text"]]

# %%
leanDf
# Out:
#               id                                              title  \
# 0     1613548461                       疫情中的印尼万隆动物园 饲料不足民众捐助肉菜水果-中新网
# 1     1521789661  Brazilian vice president refutes criticism ove...
# 2     1598593761  Bundesliga und zweite Liga in der Corona-Krise...
# 3     1639352361  Manutenzione strade: 610mila euro per i lavori...
# 4     1510387361                          【武汉肺炎】武漢男怕傳染給妻兒 樓梯間吃完餃子就走
# ...          ...                                                ...
# 9709  1523921325  Coronavirus, numero delle vittime in Cina sfio...
# 9710  1595179325  Covid-19 Piemonte. A due giorni dalla “riapert...
# 9711  1564254925  India witnessed second slowest 100 to 1,000 ju...
# 9712  1545223425                               Правительство России
# 9713  1536753925  Apple Store in India: Why Apple may have to ‘t...
#
#                                                     url  \
# 0     http://www.chinanews.com/tp/hd2011/2020/05-22/...
# 1     https://www.iol.co.za/business-report/belt-and...
# 2     https://www.stuttgarter-nachrichten.de/inhalt....
# 3     https://www.ilgiunco.net/2020/06/19/manutenzio...
# 4                        https://eunited.com.my/346105/
# ...                                                 ...
# 9709  https://it.sputniknews.com/mondo/2020021887442...
# 9710  http://www.giornale7.it/covid-19-piemonte-a-du...
# 9711  https://www.indiatoday.in/diu/story/india-seco...
# 9712                   http://government.ru/news/39123/
# 9713  https://www.gadgetsnow.com/tech-news/why-apple...
#
#                                   source_url  \
# 0                   http://www.chinanews.com
# 1                      https://www.iol.co.za
# 2     https://www.stuttgarter-nachrichten.de
# 3                   https://www.ilgiunco.net
# 4                     https://eunited.com.my
# ...                                      ...
# 9709              https://it.sputniknews.com
# 9710                 http://www.giornale7.it
# 9711               https://www.indiatoday.in
# 9712                    http://government.ru
# 9713              https://www.gadgetsnow.com
#
#                                                    text
# 0     5月22日消息，印度尼西亚西爪哇省万隆，当地的动物园面临饲料不足的窘况，园中的猛兽即将没有肉...
# 1     An indigenous child looks on during a demonstr...
# 2     1 Auch beim VfB Stuttgart wird es zu Geistersp...
# 3     GROSSETO – In seguito al decreto ministeriale ...
# 4     過年期間，童昱升只能透過視訊與妻兒見面。\n\n武汉新型冠状肺炎持续扩散，导致过年期间几家欢...
# ...                                                 ...
# 9709  Il numero di persone morte in Cina a causa del...
# 9710  Oggi pomeriggio l’Unità di Crisi della Regione...
# 9711  Till Tuesday afternoon, India reported more th...
# 9712  За последние сутки в России зарегистрировано 8...
# 9713  For the longest time, Apple fans — and industr...
#
# [9714 rows x 5 columns]

# %%
groundTruths = pd.read_csv("/shared/3/projects/benlitterer/agendaSetting/final_evaluation_data.csv")
print(groundTruths.shape)
groundTruths.head(3)
# Out:
# (4902, 14)
#   url1_lang url2_lang                pair_id  \
# 0        en        en  1484189203_1484121193
# 1        en        en  1484011097_1484011106
# 2        en        en  1484039488_1484261803
#
#                                                link1  \
# 0  https://wsvn.com/news/local/broward/police-2-m...
# 1  https://www.zdnet.com/article/autoclerk-databa...
# 2  https://www.presstelegram.com/2019/12/31/ducks...
#
#                                                link2  \
# 0  https://wsvn.com/news/local/no-swim-advisory-l...
# 1  https://securityboulevard.com/2019/10/best-wes...
# 2  https://boingboing.net/2020/01/01/woody-guthri...
#
#                                             ia_link1  \
# 0  https://web.archive.org/web/https://wsvn.com/n...
# 1  https://web.archive.org/web/https://www.zdnet....
# 2  https://web.archive.org/web/https://www.presst...
#
#                                             ia_link2  GEO  ENT  TIME  NAR  \
# 0  https://web.archive.org/web/https://wsvn.com/n...  1.5  4.0   2.0  4.0
# 1  https://web.archive.org/web/https://securitybo...  1.0  2.0   1.0  1.0
# 2  https://web.archive.org/web/https://boingboing...  5.0  4.0   3.0  4.0
#
#    Overall  STYLE      TONE
# 0      3.5    1.0  1.500000
# 1      1.0    3.5  2.500000
# 2      4.0    4.0  3.666667

# %%
#get just the english pairs 
groundTruths.loc[(groundTruths["url1_lang"] == "en") & (groundTruths["url2_lang"] == "en")].shape
# Out:
# (236, 16)

# %%
def splitIds(inStr): 
    return inStr.split("_")
#groundTruths[["id1", "id2"]] = groundTruths["pair_id"].apply(splitIds)
groundTruths["id1"] = [item[0] for item in groundTruths["pair_id"].apply(splitIds)]
groundTruths["id2"] = [item[1] for item in groundTruths["pair_id"].apply(splitIds)]

# %%
#This used to work but stopped working potentially due to pandas version error? 
#groundTruths[["id1", "id2"]] = groundTruths["pair_id"].str.split("_", expand=True)

# %%
leanDf = leanDf[["id", "text", "title"]]

# %%
#merge text for the first id, id1
leanDf1 = leanDf.rename(columns = {"id":"id1","text":"text1", "title":"title1"})
firstMerge = pd.merge(groundTruths, leanDf1, how="left", on="id1")
firstMerge.head(3)
# Out:
#   url1_lang url2_lang                pair_id  \
# 0        en        en  1484189203_1484121193
# 1        en        en  1484011097_1484011106
# 2        en        en  1484039488_1484261803
#
#                                                link1  \
# 0  https://wsvn.com/news/local/broward/police-2-m...
# 1  https://www.zdnet.com/article/autoclerk-databa...
# 2  https://www.presstelegram.com/2019/12/31/ducks...
#
#                                                link2  \
# 0  https://wsvn.com/news/local/no-swim-advisory-l...
# 1  https://securityboulevard.com/2019/10/best-wes...
# 2  https://boingboing.net/2020/01/01/woody-guthri...
#
#                                             ia_link1  \
# 0  https://web.archive.org/web/https://wsvn.com/n...
# 1  https://web.archive.org/web/https://www.zdnet....
# 2  https://web.archive.org/web/https://www.presst...
#
#                                             ia_link2  GEO  ENT  TIME  NAR  \
# 0  https://web.archive.org/web/https://wsvn.com/n...  1.5  4.0   2.0  4.0
# 1  https://web.archive.org/web/https://securitybo...  1.0  2.0   1.0  1.0
# 2  https://web.archive.org/web/https://boingboing...  5.0  4.0   3.0  4.0
#
#    Overall  STYLE      TONE         id1         id2  \
# 0      3.5    1.0  1.500000  1484189203  1484121193
# 1      1.0    3.5  2.500000  1484011097  1484011106
# 2      4.0    4.0  3.666667  1484039488  1484261803
#
#                                                text1  \
# 0  DAVIE, FLA. (WSVN) - Police need help catching...
# 1  Govt officials confirm Trump can block US comp...
# 2  Ducks defenseman Erik Gudbranson, left, knocks...
#
#                                               title1
# 0     Police: 2 men stole tools from Lowe’s in Davie
# 1  Open database leaked 179GB in customer, US gov...
# 2  Ducks are own worst enemies in sloppy loss in ...

# %%
leanDf2 = leanDf.rename(columns = {"id":"id2","text":"text2", "title":"title2"})
merged = pd.merge(firstMerge, leanDf2, how="left", on="id2")
merged.head(3)
# Out:
#   url1_lang url2_lang                pair_id  \
# 0        en        en  1484189203_1484121193
# 1        en        en  1484011097_1484011106
# 2        en        en  1484039488_1484261803
#
#                                                link1  \
# 0  https://wsvn.com/news/local/broward/police-2-m...
# 1  https://www.zdnet.com/article/autoclerk-databa...
# 2  https://www.presstelegram.com/2019/12/31/ducks...
#
#                                                link2  \
# 0  https://wsvn.com/news/local/no-swim-advisory-l...
# 1  https://securityboulevard.com/2019/10/best-wes...
# 2  https://boingboing.net/2020/01/01/woody-guthri...
#
#                                             ia_link1  \
# 0  https://web.archive.org/web/https://wsvn.com/n...
# 1  https://web.archive.org/web/https://www.zdnet....
# 2  https://web.archive.org/web/https://www.presst...
#
#                                             ia_link2  GEO  ENT  TIME  NAR  \
# 0  https://web.archive.org/web/https://wsvn.com/n...  1.5  4.0   2.0  4.0
# 1  https://web.archive.org/web/https://securitybo...  1.0  2.0   1.0  1.0
# 2  https://web.archive.org/web/https://boingboing...  5.0  4.0   3.0  4.0
#
#    Overall  STYLE      TONE         id1         id2  \
# 0      3.5    1.0  1.500000  1484189203  1484121193
# 1      1.0    3.5  2.500000  1484011097  1484011106
# 2      4.0    4.0  3.666667  1484039488  1484261803
#
#                                                text1  \
# 0  DAVIE, FLA. (WSVN) - Police need help catching...
# 1  Govt officials confirm Trump can block US comp...
# 2  Ducks defenseman Erik Gudbranson, left, knocks...
#
#                                               title1  \
# 0     Police: 2 men stole tools from Lowe’s in Davie
# 1  Open database leaked 179GB in customer, US gov...
# 2  Ducks are own worst enemies in sloppy loss in ...
#
#                                                text2  \
# 0  DEERFIELD BEACH, FLA. (WSVN) - A no-swim advis...
# 1  The latest huge unsecured cloud storage find i...
# 2  Woody Guthrie's 1943 New Year's Resolutions ar...
#
#                                               title2
# 0   No-swim advisory lifted for Deerfield Beach Pier
# 1  Best Western’s Massive Data Leak: 179GB Amazon...
# 2  Woody Guthrie's 1943 New Year's Resolutions ar...

# %%
#NOTE: when we do inner joins, we go down to only 4901 articles above meaning that we 
#don't have the data for one article

# %%
#check out which articles have na values 
#hasTextNa = merged[merged[["title1", "title2", "text1", "text2"]].isna().any(axis=1)]
#hasTextNa.loc[4491]

# %%
#do some more thoughtful dropping of na's 
#merged[["title1", "title2", "text1", "text2"]] = merged[["title1", "title2", "text1", "text2"]].fillna("")

# %%
mergedClean = merged.dropna(subset=["title1", "text1"], how="all").dropna(subset=["title2", "text2"], how="all")

# %%
#all of the common articles : 
removed = list(set(merged["pair_id"]) - set(mergedClean["pair_id"]))

removedDf = merged[merged["pair_id"].isin(removed)]

# %%
list(removedDf["id2"])
# Out:
# ['1568361410']

# %%
#article that we lost: completely empty....
#for some reason we only have empty html of this file (1568361410)
merged.loc[merged["pair_id"] == "1525127987_1568361410", "link2"]
# Out:
# 2659    https://www.onet.pl/?utm_source=_viasg_fakt&ut...
# Name: link2, dtype: object

# %%
#do some more thoughtful dropping of na's 
#this time for empty text and title fields 
mergedClean[["title1", "title2", "text1", "text2"]] = mergedClean[["title1", "title2", "text1", "text2"]].fillna("")

mergedClean["titleText1"] = mergedClean["title1"] + mergedClean["text1"]
mergedClean["titleText2"] = mergedClean["title2"] + mergedClean["text2"]

#NOTE: we lose 29 records here
#NOTE: we lose 10 records here according to the SemEval paper 
def splitLen(inStr): 
    return len(inStr.split())

#we want to keep only the data for which we have over 2 tokens 
mergedClean = mergedClean[(mergedClean["titleText1"].apply(len) > 0) & (mergedClean["titleText2"].apply(len) > 0)]
len(mergedClean)
# Out:
# 4901

# %%
#NOTE: here we keep all 236 records 
mergedEn = mergedClean[(mergedClean["url1_lang"] == "en") & (mergedClean["url2_lang"] == "en")]
mergedEn.shape
# Out:
# (236, 22)

# %%
mergedEn.to_csv("/shared/3/projects/newsDiffusion/data/processed/enTestData.tsv", sep="\t")
