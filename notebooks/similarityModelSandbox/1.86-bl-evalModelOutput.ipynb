# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#load in the pickled output data
inDir = "/home/blitt/projects/localNews/models/sentEmbeddings/1.0-LongformerRDrop/outputs/4_2_25_5_1500_en"
inDir = inDir.rstrip("/")

corrDf = pd.read_pickle(inDir + "/corrDf.pickle")
lossDf = pd.read_pickle(inDir + "/lossDf.pickle")

# %%
sns.lineplot(data=lossDf, x="lossIndex", y="lossList")
# Out:
# <AxesSubplot:xlabel='lossIndex', ylabel='lossList'>

# %%
print(corrDf)
# Out:
#     Overall
# 0 -0.153241
# 1  0.789784
# 2  0.815750
# 3  0.835875
# 4  0.827926

# %%
sns.lineplot(data=corrDf)
plt.title("Training Over all Objectives")
plt.ylim(0, 1)
plt.xlim(0, 2)
#Grabbed this line from: https://www.statology.org/seaborn-legend-outside/
plt.legend(bbox_to_anchor=(1.02, 1), loc='upper left', borderaxespad=0)
